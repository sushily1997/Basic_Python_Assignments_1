# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/Basic_Python_Assignments_1/blob/main/SQL_Data%20Definition%20Language(DDL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**DDL (Data Definition Language)**

# %% [markdown]
# ![SQL_1_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_1_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_1_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_1_4.jpg](data:image/jpeg;base64,...)
