# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/Basic_Python_Assignments_1/blob/main/Virtual_env.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![vs.PNG](data:image/png;base64,...)

# %% [markdown]
# ![jupyter.PNG](data:image/png;base64,...)
