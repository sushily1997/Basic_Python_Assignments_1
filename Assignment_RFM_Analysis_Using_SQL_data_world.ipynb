# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/Basic_Python_Assignments_1/blob/main/Assignment_RFM_Analysis_Using_SQL_data_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![sql.1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql.2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql.3.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql.5.PNG](data:image/png;base64,...)
