# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/Basic_Python_Assignments_1/blob/main/SQL_Practic_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SQL_practice Day 1**

# %% [markdown]
# ![SQL_Ans.PNG](data:image/png;base64,...)
