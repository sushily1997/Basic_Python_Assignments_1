# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/Basic_Python_Assignments_1/blob/main/SQL_Practice_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SQL_Practice_Day2**

# %% [markdown]
# ![sql_day2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql_1day2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql_2day2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql_3day2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![sql_4day2.PNG](data:image/png;base64,...)
