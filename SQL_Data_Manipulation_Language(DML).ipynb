# %% [markdown]
# <a href="https://colab.research.google.com/github/sushily1997/Basic_Python_Assignments_1/blob/main/SQL_Data_Manipulation_Language(DML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**DML(Data Manipulation Language)**

# %% [markdown]
# ![SQL_2_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_2_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_2_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_2_4.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_2_5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![SQL_2_6.jpeg](data:image/jpeg;base64,...)
